# %% [markdown]
# # HR ANALYTICS ABSENTEEISM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Downloads/MFGEmployees4 2.csv")

# %%
data
# Out:
#       EmployeeNumber    Surname GivenName Gender             City  \
# 0                  1  Gutierrez     Molly      F          Burnaby
# 1                  2   Hardwick   Stephen      M        Courtenay
# 2                  3    Delgado   Chester      M         Richmond
# 3                  4      Simon     Irene      F         Victoria
# 4                  5   Delvalle    Edward      M  New Westminster
# ...              ...        ...       ...    ...              ...
# 8331            8332   Coniglio    Bianca      F          Langley
# 8332            8333        Cox    Jimmie      M          Montney
# 8333            8334    Hawkins      Mary      F   West Vancouver
# 8334            8335    Proctor   Theresa      F        Vancouver
# 8335            8336     Salter   Charles      M        Vancouver
#
#           JobTitle    DepartmentName    StoreLocation Division        Age  \
# 0            Baker            Bakery          Burnaby   Stores  32.028816
# ...

# %%
data.head()
# Out:
#    EmployeeNumber    Surname GivenName Gender             City JobTitle  \
# 0               1  Gutierrez     Molly      F          Burnaby    Baker
# 1               2   Hardwick   Stephen      M        Courtenay    Baker
# 2               3    Delgado   Chester      M         Richmond    Baker
# 3               4      Simon     Irene      F         Victoria    Baker
# 4               5   Delvalle    Edward      M  New Westminster    Baker
#
#   DepartmentName    StoreLocation Division        Age  LengthService  \
# 0         Bakery          Burnaby   Stores  32.028816       6.018478
# 1         Bakery          Nanaimo   Stores  40.320902       5.532445
# 2         Bakery         Richmond   Stores  48.822047       4.389973
# 3         Bakery         Victoria   Stores  44.599357       3.081736
# 4         Bakery  New Westminster   Stores  35.697876       3.619091
#
#    AbsentHours BusinessUnit
# 0    36.577306       Stores
# 1    30.165072       Stores
# 2    83.807798       Stores
# ...

# %%
data.tail()
# Out:
#       EmployeeNumber   Surname GivenName Gender            City      JobTitle  \
# 8331            8332  Coniglio    Bianca      F         Langley       Cashier
# 8332            8333       Cox    Jimmie      M         Montney       Cashier
# 8333            8334   Hawkins      Mary      F  West Vancouver       Cashier
# 8334            8335   Proctor   Theresa      F       Vancouver  Dairy Person
# 8335            8336    Salter   Charles      M       Vancouver  Dairy Person
#
#         DepartmentName   StoreLocation Division        Age  LengthService  \
# 8331  Customer Service         Langley   Stores  46.057544       4.838288
# 8332  Customer Service    Fort St John   Stores  34.455490       2.427274
# 8333  Customer Service  West Vancouver   Stores  58.347160       4.009393
# 8334             Dairy       Vancouver   Stores  43.340616       6.154837
# 8335             Dairy       Vancouver   Stores  46.192782       5.174722
#
#       AbsentHours BusinessUnit
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  8336 non-null   int64
#  1   Surname         8336 non-null   object
#  2   GivenName       8336 non-null   object
#  3   Gender          8336 non-null   object
#  4   City            8336 non-null   object
#  5   JobTitle        8336 non-null   object
#  6   DepartmentName  8336 non-null   object
#  7   StoreLocation   8336 non-null   object
#  8   Division        8336 non-null   object
#  9   Age             8336 non-null   float64
#  10  LengthService   8336 non-null   float64
#  11  AbsentHours     8336 non-null   float64
#  12  BusinessUnit    8336 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 846.8+ KB

# %%
data.describe()
# Out:
#        EmployeeNumber          Age  LengthService  AbsentHours
# count     8336.000000  8336.000000    8336.000000  8336.000000
# mean      4168.500000    42.007086       4.782910    61.283978
# std       2406.540255     9.939798       2.462990    49.038365
# min          1.000000     3.504743       0.012098     0.000000
# 25%       2084.750000    35.298748       3.575892    19.127590
# 50%       4168.500000    42.114924       4.600248    56.005808
# 75%       6252.250000    48.666943       5.623922    94.284692
# max       8336.000000    77.938003      43.735239   272.530123

# %% [markdown]
# ## As in the problem statement data below 18 and above 65 should be removed from the dataset

# %%
data = data.drop(data[data['Age']<18].index,axis=0)

# %%
data = data.drop(data[data['Age']>65].index,axis=0)

# %%
data.head()
# Out:
#    EmployeeNumber    Surname GivenName Gender             City JobTitle  \
# 0               1  Gutierrez     Molly      F          Burnaby    Baker
# 1               2   Hardwick   Stephen      M        Courtenay    Baker
# 2               3    Delgado   Chester      M         Richmond    Baker
# 3               4      Simon     Irene      F         Victoria    Baker
# 4               5   Delvalle    Edward      M  New Westminster    Baker
#
#   DepartmentName    StoreLocation Division        Age  LengthService  \
# 0         Bakery          Burnaby   Stores  32.028816       6.018478
# 1         Bakery          Nanaimo   Stores  40.320902       5.532445
# 2         Bakery         Richmond   Stores  48.822047       4.389973
# 3         Bakery         Victoria   Stores  44.599357       3.081736
# 4         Bakery  New Westminster   Stores  35.697876       3.619091
#
#    AbsentHours BusinessUnit
# 0    36.577306       Stores
# 1    30.165072       Stores
# 2    83.807798       Stores
# ...

# %%
data.EmployeeNumber.value_counts()
# Out:
# 1       1
# 5550    1
# 5563    1
# 5562    1
# 5561    1
#        ..
# 2773    1
# 2772    1
# 2771    1
# 2770    1
# 8336    1
# Name: EmployeeNumber, Length: 8165, dtype: int64

# %% [markdown]
# no duplicate employee number found

# %%
data.isnull().sum()
# Out:
# EmployeeNumber    0
# Surname           0
# GivenName         0
# Gender            0
# City              0
# JobTitle          0
# DepartmentName    0
# StoreLocation     0
# Division          0
# Age               0
# LengthService     0
# AbsentHours       0
# BusinessUnit      0
# dtype: int64

# %% [markdown]
# No null values found

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# no duplicate found

# %%
data = data.drop(['EmployeeNumber', 'Surname','GivenName'], axis = 1)

# %%
data
# Out:
#      Gender             City      JobTitle    DepartmentName    StoreLocation  \
# 0         F          Burnaby         Baker            Bakery          Burnaby
# 1         M        Courtenay         Baker            Bakery          Nanaimo
# 2         M         Richmond         Baker            Bakery         Richmond
# 3         F         Victoria         Baker            Bakery         Victoria
# 4         M  New Westminster         Baker            Bakery  New Westminster
# ...     ...              ...           ...               ...              ...
# 8331      F          Langley       Cashier  Customer Service          Langley
# 8332      M          Montney       Cashier  Customer Service     Fort St John
# 8333      F   West Vancouver       Cashier  Customer Service   West Vancouver
# 8334      F        Vancouver  Dairy Person             Dairy        Vancouver
# 8335      M        Vancouver  Dairy Person             Dairy        Vancouver
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8165 entries, 0 to 8335
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          8165 non-null   object
#  1   City            8165 non-null   object
#  2   JobTitle        8165 non-null   object
#  3   DepartmentName  8165 non-null   object
#  4   StoreLocation   8165 non-null   object
#  5   Division        8165 non-null   object
#  6   Age             8165 non-null   float64
#  7   LengthService   8165 non-null   float64
#  8   AbsentHours     8165 non-null   float64
#  9   BusinessUnit    8165 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 701.7+ KB

# %%
sns.countplot(x=data.Gender)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
data.describe(include="O")
# Out:
#        Gender       City JobTitle    DepartmentName StoreLocation Division  \
# count    8165       8165     8165              8165          8165     8165
# unique      2        243       47                21            40        6
# top         M  Vancouver  Cashier  Customer Service     Vancouver   Stores
# freq     4148       1751     1663              1695          1807     7993
#
#        BusinessUnit
# count          8165
# unique            2
# top          Stores
# freq           7993

# %%
data.describe()
# Out:
#                Age  LengthService  AbsentHours
# count  8165.000000    8165.000000  8165.000000
# mean     41.985633       4.788871    60.471110
# std       9.276915       2.478484    47.107030
# min      18.204720       0.053279     0.000000
# 25%      35.456296       3.582605    20.067078
# 50%      42.097897       4.597999    55.862962
# 75%      48.513876       5.623582    93.381290
# max      65.000000      43.735239   252.193535

# %%
sns.countplot(x=data.BusinessUnit)
# Out:
# <AxesSubplot:xlabel='BusinessUnit', ylabel='count'>

# %% [markdown]
# ## Grouping different job titles

# %%
data.JobTitle.value_counts()
# Out:
# Cashier                            1663
# Dairy Person                       1476
# Meat Cutter                        1461
# Baker                              1375
# Produce Clerk                      1101
# Shelf Stocker                       701
# Bakery Manager                       45
# Store Manager                        38
# Processed Foods Manager              34
# Meats Manager                        34
# Customer Service Manager             32
# Produce Manager                      32
# Accounting Clerk                     17
# Accounts Receiveable Clerk           15
# Accounts Payable Clerk               14
# Auditor                              14
# Trainer                              14
# HRIS Analyst                         13
# Recruiter                            12
# Benefits Admin                       11
# Labor Relations Analyst              11
# Systems Analyst                      10
# Compensation Analyst                  8
# ...

# %%
def jobtitles(job):
    if 'director' in job.lower():
        job = 'Director'
    if 'clerk' in job.lower():
        job = 'Clerk'
    if 'manager' in job.lower():
        job = 'Manager'
    if 'analyst' in job.lower():
        job = 'Analyst'
    if 'assistant' in job.lower():
        job = 'Assistant'
    if 'vp' in job.lower():
        job='VP'
    else:
        job=job
    return job

# %%
data['JobTitle']=data['JobTitle'].apply(jobtitles)

# %%
sns.countplot(y=data.JobTitle, order = data['JobTitle'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='JobTitle'>

# %%
sns.countplot(y=data.DepartmentName, order = data['DepartmentName'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='DepartmentName'>

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=data.StoreLocation, order = data['StoreLocation'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='StoreLocation'>

# %%
sns.countplot(y=data.Division, order = data['Division'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Division'>

# %%
data[["City"]].value_counts()[:10].plot(kind = 'pie',autopct ='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
sns.displot(data['Age'],kde = True)

# %%
sns.displot(data['LengthService'],kde = True)

# %%
sns.displot(data['AbsentHours'],kde = True)

# %% [markdown]
# 1. Age is Normally Distributed.
# 2. LengthService is Slightly Skewed Right.
# 3. AbsentHours is Log Normally Distributed i.e. skewed towards right which means:
#     There are very few employee which are absent for longer period of time and vice versa...

# %%
data.corr()
# Out:
#                     Age  LengthService  AbsentHours
# Age            1.000000       0.056234     0.824613
# LengthService  0.056234       1.000000    -0.046692
# AbsentHours    0.824613      -0.046692     1.000000

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x=data['Age'],y=data['AbsentHours'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='AbsentHours'>

# %%
sns.scatterplot(x=data['LengthService'],y=data['AbsentHours'])
# Out:
# <AxesSubplot:xlabel='LengthService', ylabel='AbsentHours'>

# %% [markdown]
# ## Barplot

# %%
sns.barplot(x=data['Gender'],y=data['AbsentHours'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='AbsentHours'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x= 'Gender', y='AbsentHours', data = data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='AbsentHours'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x= 'AbsentHours', y='StoreLocation', data = data)
# Out:
# <AxesSubplot:xlabel='AbsentHours', ylabel='StoreLocation'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x= 'AbsentHours', y='JobTitle', data = data)
# Out:
# <AxesSubplot:xlabel='AbsentHours', ylabel='JobTitle'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x= 'AbsentHours', y='DepartmentName', data = data)
# Out:
# <AxesSubplot:xlabel='AbsentHours', ylabel='DepartmentName'>

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data.to_excel("HR ABSENTEEISM.xlsx")

# %% [markdown]
# ## Final Insights:-

# %% [markdown]
# 1. The ratio of men and women working are almost equal.
# 2. The employees working in Stores are more as compaired to Headoffice.
# 3. Most of the stores are present in Vancouver,Victoria,Nanaoimo, New Westminster in the following order.
# 4. Most of the people are working as Cashier then as Dairy Persons
# 5. Age and AbsentHours are highly correlated. we can say higher the age higher will be the absenthours.
# 6. ScatterPlot shows the relations between Age and AbsentHours as age increases, AbsentHours also increses.
# 7. From the Barplot between Gender and AbsentHours we can say that female ought to have more absent hours.
# 8. And from Boxplot we can say that females have more outliers.
# 9. As we can see from the boxplot between AbsentHours and StoreLocation Vancouver has the most outiers than any             store location which means, many employees with high number of absent hours are from Vancouver.
# 10. We can see employees who were working as Cashiers were comparatively Absent more.
# 11. Customer Service' and 'Bakery' have the most outliers i.e Employee from these department have the Most Absent            Hours
